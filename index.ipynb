# %% [markdown]
# # EDA with Pandas - Cumulative Lab
#
# ## Introduction
#
# In this section, you've learned a lot about importing, cleaning up, analyzing (using descriptive statistics) and visualizing data. In this cumulative lab, you'll get a chance to practice all of these skills with the Ames Housing dataset, which contains information about home sales in Ames, Iowa between 2006 and 2010.
#
# ## Objectives
#
# You will be able to:
#
# * Practice loading data with pandas
# * Practice calculating measures of centrality and dispersion with pandas
# * Practice creating subsets of data with pandas
# * Practice using data visualizations to explore data, and interpreting those visualizations
# * Perform a full exploratory data analysis process to gain insight about a dataset

# %% [markdown]
# ## Your Task: Explore the Ames Housing Dataset with Pandas
#
# ![aerial photo of a neighborhood](images/neighborhood_aerial.jpg)
#
# Photo by <a href="https://unsplash.com/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Matt Donders</a> on <a href="/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
#
# Each record (row) in this dataset represents a home that was sold in Ames, IA.
#
# Each feature (column) in this dataset is some attribute of that home sale. You can view the file `data/data_description.txt` in this repository for a full explanation of all variables in this dataset — 80 columns in total.
#
# We are going to focus on the following features:
#
# **SalePrice**: `Sale price of the house in dollars`
#
# **TotRmsAbvGrd**: `Total rooms above grade (does not include bathrooms)`
#
# **OverallCond**: `Rates the overall condition of the house`
# ```
#        10	Very Excellent
#        9	 Excellent
#        8	 Very Good
#        7	 Good
#        6	 Above Average
#        5	 Average
#        4	 Below Average
#        3	 Fair
#        2	 Poor
#        1	 Very Poor
# ```
#
# **YrSold**: `Year Sold (YYYY)`
#
# **YearBuilt**: `Original construction date`
#
# **LandSlope**: `Slope of property`
# ```
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
# ```

# %% [markdown]
# ### Requirements
#
# In this lab you will use your data munging and visualization skills to conduct an exploratory analysis of the dataset.
#
# #### 1. Load the Dataset with Pandas
#
# Import pandas with the standard alias `pd` and load the data into a dataframe with the standard name `df`.
#
# #### 2. Explore Data Distributions
#
# Produce summary statistics, visualizations, and interpretive text describing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# #### 3. Explore Differences between Subsets
#
# Separate the data into subsets based on `OverallCond`, then demonstrate how this split impacts the distribution of `SalePrice`.
#
# #### 4. Explore Correlations
#
# Find the features that have the strongest positive and negative correlations with `SalePrice`, and produce plots representing these relationships.
#
# #### 5. Engineer and Explore a New Feature
#
# Create a new feature `Age`, which represents the difference between the year sold and the year built, and plot the relationship between the age and sale price.

# %% [markdown]
# ## 1. Load the Dataset with Pandas
#
# In the cell below, import:
# * `pandas` with the standard alias `pd`
# * `matplotlib.pyplot` with the standard alias `plt`
#
# And set `%matplotlib inline` so the graphs will display immediately below the cell that creates them.

# %%
# Your code here
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib  inline

# %% [markdown]
# Now, use pandas to open the file located at `data/ames.csv` ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Specify the argument `index_col=0` in order to avoid creating an extra `Id` column. Name the resulting dataframe `df`.

# %%
# Your code here
df=pd.read_csv('data\\ames.csv',index_col=0)

# %% [markdown]
# The following code checks that you loaded the data correctly:

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %% [markdown]
# Inspect the contents of the dataframe:

# %%
# Run this cell without changes
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# Run this cell without changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## 2. Explore Data Distributions
#
# Write code to produce histograms showing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# Each histogram should have appropriate title and axes labels, as well as a black vertical line indicating the mean of the dataset. See the documentation for [plotting histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html), [customizing axes](https://matplotlib.org/stable/api/axes_api.html#axis-labels-title-and-legend), and [plotting vertical lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html#matplotlib.axes.Axes.axvline) as needed.

# %% [markdown]
# ### Sale Price
#
# In the cell below, produce a histogram for `SalePrice`.

# %%
# Your code here

# Plot histogram for SalePrice
plt.figure(figsize=(8, 6))
plt.hist(df['SalePrice'], bins=30, color='skyblue', edgecolor='black')
plt.axvline(df['SalePrice'].mean(), color='black', linestyle='dashed', linewidth=2)
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.title('Distribution of SalePrice')
plt.grid(True)
plt.show()

# Plot histogram for TotRmsAbvGrd
plt.figure(figsize=(8, 6))
plt.hist(df['TotRmsAbvGrd'], bins=20, color='lightgreen', edgecolor='black')
plt.axvline(df['TotRmsAbvGrd'].mean(), color='black', linestyle='dashed', linewidth=2)
plt.xlabel('TotRmsAbvGrd')
plt.ylabel('Frequency')
plt.title('Distribution of TotRmsAbvGrd')
plt.grid(True)
plt.show()

# Plot histogram for OverallCond
plt.figure(figsize=(8, 6))
plt.hist(df['OverallCond'], bins=10, color='lightcoral', edgecolor='black')
plt.axvline(df['OverallCond'].mean(), color='black', linestyle='dashed', linewidth=2)
plt.xlabel('OverallCond')
plt.ylabel('Frequency')
plt.title('Distribution of OverallCond')
plt.grid(True)
plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
def describe_statistics(data, columns):
    results = {}
    for col in columns:
        results[col] = {
            'Mean': data[col].mean(),
            'Median': data[col].median(),
            'Standard Deviation': data[col].std()
        }
    return pd.DataFrame(results)
columns_to_describe = ['SalePrice', 'TotRmsAbvGrd', 'OverallCond']
statistics_df = describe_statistics(df, columns_to_describe)
print(statistics_df)
# Out:
#                         SalePrice  TotRmsAbvGrd  OverallCond
# Mean                180921.195890      6.517808     5.575342
# Median              163000.000000      6.000000     5.000000
# Standard Deviation   79442.502883      1.625393     1.112799

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
"""
SalePrice: The average sale price of a house is around $180,921, with a comparatively high price variety reflected by a standard deviation of around $79,442. This indicates that the information contains a wide range of property values.

TotRmsAbvGrd: The average number of rooms above ground in the dwellings is about 6.52, with a very minor variation shown by a standard deviation of about 1.63. This implies that the majority of residences have a comparable amount of rooms.

OverallCond: The average overall condition rating of houses is approximately 5.58, with a little variation shown by the standard deviation of approximately 1.11. This indicates that the general condition of houses is pretty stable.
SalePrice: The average sale price of a house is around $180,921, with a comparatively high price variety reflected by a standard deviation of around $79,442. This indicates that the information contains a wide range of property values.

TotRmsAbvGrd: The average number of rooms above ground in the dwellings is about 6.52, with a very minor variation shown by a standard deviation of about 1.63. This implies that the majority of residences have a comparable amount of rooms.

OverallCond: The average overall condition rating of houses is approximately 5.58, with a little variation shown by the standard deviation of approximately 1.11. This indicates that the general condition of houses is pretty stable.

"""
# Out:
# '\nSalePrice: The average sale price of a house is around $180,921, with a comparatively high price variety reflected by a standard deviation of around $79,442. This indicates that the information contains a wide range of property values.\n\nTotRmsAbvGrd: The average number of rooms above ground in the dwellings is about 6.52, with a very minor variation shown by a standard deviation of about 1.63. This implies that the majority of residences have a comparable amount of rooms.\n\nOverallCond: The average overall condition rating of houses is approximately 5.58, with a little variation shown by the standard deviation of approximately 1.11. This indicates that the general condition of houses is pretty stable.\nSalePrice: The average sale price of a house is around $180,921, with a comparatively high price variety reflected by a standard deviation of around $79,442. This indicates that the information contains a wide range of property values.\n\nTotRmsAbvGrd: The average number of rooms
# ...

# %% [markdown]
# ### Total Rooms Above Grade
#
# In the cell below, produce a histogram for `TotRmsAbvGrd`.

# %%
# Your code here
# Plot histogram for TotRmsAbvGrd
plt.figure(figsize=(8, 6))
plt.hist(df['TotRmsAbvGrd'], bins=20, color='skyblue', edgecolor='black')
plt.axvline(df['TotRmsAbvGrd'].mean(), color='black', linestyle='dashed', linewidth=2, label='Mean')
plt.xlabel('Total Rooms Above Grade')
plt.ylabel('Frequency')
plt.title('Distribution of Total Rooms Above Grade')
plt.legend();

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
# Calculate mean, median, and standard deviation
x,y,z = df['TotRmsAbvGrd'].mean(),df['TotRmsAbvGrd'].median(),df['TotRmsAbvGrd'].std()
x,y,z
# Out:
# (6.517808219178082, 6.0, 1.625393290584064)

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
"""
Mean: The mean value is roughly 6.52, indicating that there are approximately 6.52 total rooms above grade in the residences in the sample.

The median value is 6.0, indicating that half of the houses have 6 or fewer rooms above grade and half have 7 or more.

The standard deviation is around 1.63, and it measures the variability or spread of the data. A larger standard deviation indicates that the number of rooms above grade in the residences deviates from the mean more.
The mean and median offer us a notion of the normal number of rooms above grade in the residences, while the standard deviation shows how far this number deviates from the mean, indicating the level of variability in the data.

"""
# Out:
# '\nMean: The mean value is roughly 6.52, indicating that there are approximately 6.52 total rooms above grade in the residences in the sample.\n\nThe median value is 6.0, indicating that half of the houses have 6 or fewer rooms above grade and half have 7 or more.\n\nThe standard deviation is around 1.63, and it measures the variability or spread of the data. A larger standard deviation indicates that the number of rooms above grade in the residences deviates from the mean more.\nThe mean and median offer us a notion of the normal number of rooms above grade in the residences, while the standard deviation shows how far this number deviates from the mean, indicating the level of variability in the data.\n\n'

# %% [markdown]
# ### Overall Condition
#
# In the cell below, produce a histogram for `OverallCond`.

# %%
# Your code here
# Plot histogram for 'OverallCond'
plt.figure(figsize=(8, 6))
plt.hist(df['OverallCond'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Overall Condition')
plt.ylabel('Frequency')
plt.title('Histogram of Overall Condition Ratings')
plt.grid(True)
plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
a,b,c = df['OverallCond'].mean(),df['OverallCond'].median(),df['OverallCond'].std()
a,b,c
# Out:
# (5.575342465753424, 5.0, 1.1127993367127367)

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
"""
The average overall condition grade of the dwellings is around 5.58.
The average overall condition rating is 5.0. This means that half of the dwellings are in poor condition, while the other half are in good shape.
Standard deviation: The overall condition ratings have a standard deviation of about 1.11. The spread or dispersion of the ratings around the mean is measured by this value. A lower standard deviation implies that the ratings are closer to the mean, whereas a higher standard deviation indicates that there is more variety.
To summarize, the majority of the houses in the sample have an overall condition rating of 5 or higher, with considerable fluctuation above and below this value. The standard deviation indicates that the general situation is favorable.
"""
# Out:
# '\nThe average overall condition grade of the dwellings is around 5.58.\nThe average overall condition rating is 5.0. This means that half of the dwellings are in poor condition, while the other half are in good shape.\nStandard deviation: The overall condition ratings have a standard deviation of about 1.11. The spread or dispersion of the ratings around the mean is measured by this value. A lower standard deviation implies that the ratings are closer to the mean, whereas a higher standard deviation indicates that there is more variety.\nTo summarize, the majority of the houses in the sample have an overall condition rating of 5 or higher, with considerable fluctuation above and below this value. The standard deviation indicates that the general situation is favorable.\n'

# %% [markdown]
# ## 3. Explore Differences between Subsets
#
# As you might have noted in the previous step, the overall condition of the house seems like we should treat it as more of a categorical variable, rather than a numeric variable.
#
# One useful way to explore a categorical variable is to create subsets of the full dataset based on that categorical variable, then plot their distributions based on some other variable. Since this dataset is traditionally used for predicting the sale price of a house, let's use `SalePrice` as that other variable.
#
# In the cell below, create three variables, each of which represents a record-wise subset of `df` (meaning, it has the same columns as `df`, but only some of the rows).
#
# * `below_average_condition`: home sales where the overall condition was less than 5
# * `average_condition`: home sales where the overall condition was exactly 5
# * `above_average_condition`: home sales where the overall condition was greater than 5

# %%
 #Replace None with appropriate code
below_average_condition = df[df['OverallCond'] < 5]
average_condition = df[df['OverallCond'] == 5]
above_average_condition = df[df['OverallCond'] > 5]

# %% [markdown]
# The following code checks that you created the subsets correctly:

# %%
# Run this cell without changes

# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551

# %% [markdown]
# The following code will produce a plot of the distributions of sale price for each of these subsets:

# %%
# Run this cell without changes

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="cyan",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="gray",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses")
ax.legend();

# %% [markdown]
# Interpret the plot above. What does it tell us about these overall condition categories, and the relationship between overall condition and sale price? Is there anything surprising?

# %%
# Replace None with appropriate text
"""
We can see the following from the plot:


The distribution of sale prices for houses in better condition (cyan bars) is higher, indicating that residences in better condition sell for more money.
The distribution of selling prices for houses in below-average condition (yellow bars) is lower, implying that residences in inferior condition have lower sale values overall.
Average-condition houses (gray bars) have a sale price distribution that lies between the above-average and below-average categories.
This study supports the notion that a house's general condition has a major impact on its sale price. It should come as no surprise that residences in better condition command higher values, while those in worse shape command lower prices. This information can be valuable for real estate investors and buyers looking to understand how overall condition influences the market value of a property.
"""
# Out:
# "\nWe can see the following from the plot:\n\n\nThe distribution of sale prices for houses in better condition (cyan bars) is higher, indicating that residences in better condition sell for more money.\nThe distribution of selling prices for houses in below-average condition (yellow bars) is lower, implying that residences in inferior condition have lower sale values overall.\nAverage-condition houses (gray bars) have a sale price distribution that lies between the above-average and below-average categories.\nThis study supports the notion that a house's general condition has a major impact on its sale price. It should come as no surprise that residences in better condition command higher values, while those in worse shape command lower prices. This information can be valuable for real estate investors and buyers looking to understand how overall condition influences the market value of a property.\n"

# %% [markdown]
# ## 4. Explore Correlations
#
# To understand more about what features of these homes lead to higher sale prices, let's look at some correlations. We'll return to using the full `df`, rather than the subsets.
#
# In the cell below, print out both the name of the column and the Pearson correlation for the column that is ***most positively correlated*** with `SalePrice` (other than `SalePrice`, which is perfectly correlated with itself).
#
# We'll only check the correlations with some kind of numeric data type.
#
# You can import additional libraries, although it is possible to do this just using pandas.

# %%
# Your code here
# Your code here
correlations = df.corr()['SalePrice']

# Find the column with the highest positive correlation (excluding 'SalePrice')
most_positively_correlated_column = correlations.drop('SalePrice').idxmax()
positively_correlated_value = correlations[most_positively_correlated_column]
most_positively_correlated_column,positively_correlated_value
# Out:
# C:\Users\Amell\AppData\Local\Temp\ipykernel_10924\1702901210.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = df.corr()['SalePrice']
# ('OverallQual', 0.7909816005838053)

# %% [markdown]
# Now, find the ***most negatively correlated*** column:

# %%
# Your code here
df["SalePrice"] = pd.to_numeric(df["SalePrice"], errors='coerce')

# Calculate correlations
correlations = df.corr(numeric_only=True)['SalePrice']

# Drop the 'SalePrice' column and find the most negatively correlated column
most_negatively_correlated_column = correlations.drop('SalePrice').idxmin()
pearson_corr2 = correlations[most_negatively_correlated_column]

most_negatively_correlated_column, pearson_corr2
# Out:
# ('KitchenAbvGr', -0.13590737084214105)

# %% [markdown]
# Once you have your answer, edit the code below so that it produces a box plot of the relevant columns.

# %%
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

# Plot distribution of column with highest positive correlation
sns.boxplot(
    x=df[most_positively_correlated_column],
    y=df["SalePrice"],
    ax=ax1
)

# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df[most_negatively_correlated_column],
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title("Most Positively Correlated Column")
ax1.set_xlabel(most_positively_correlated_column)
ax1.set_ylabel("Sale Price")

ax2.set_title("Most Negatively Correlated Column")
ax2.set_xlabel(most_negatively_correlated_column)
ax2.set_ylabel("Sale Price");

# %% [markdown]
# Interpret the results below. Consult `data/data_description.txt` as needed.

# %%
# Replace None with appropriate text
"""
KitchenAbvGr: The column "KitchenAbvGr" has a negative association with the column "SalePrice" of about -0.136. This means that when the number of above-ground kitchens in a house grows, the sale price tends to fall significantly. However, the correlation is relatively modest, implying that the number of kitchens and the sale price may not have a significant linear relationship.


OverallQual: The column "OverallQual" shows a high positive association with the column "SalePrice" of around 0.791. This suggests that as a house's overall quality improves, its sale price tends to rise dramatically. A higher "OverallQual" value indicates that the house is of greater quality, and purchasers are ready to pay more for homes of higher overall quality.
"OverallQual" appears to be a substantial factor influencing house sale prices, whilst "KitchenAbvGr" appears to have a somewhat weaker influence. It is critical to examine these linkages when examining the factors influencing property sale prices.

"""
# Out:
# '\nKitchenAbvGr: The column "KitchenAbvGr" has a negative association with the column "SalePrice" of about -0.136. This means that when the number of above-ground kitchens in a house grows, the sale price tends to fall significantly. However, the correlation is relatively modest, implying that the number of kitchens and the sale price may not have a significant linear relationship.\n\n\nOverallQual: The column "OverallQual" shows a high positive association with the column "SalePrice" of around 0.791. This suggests that as a house\'s overall quality improves, its sale price tends to rise dramatically. A higher "OverallQual" value indicates that the house is of greater quality, and purchasers are ready to pay more for homes of higher overall quality.\n"OverallQual" appears to be a substantial factor influencing house sale prices, whilst "KitchenAbvGr" appears to have a somewhat weaker influence. It is critical to examine these linkages when examining the factors influencing property s
# ...

# %% [markdown]
# ## 5. Engineer and Explore a New Feature
#
# Here the code is written for you, all you need to do is interpret it.
#
# We note that the data spans across several years of sales:

# %%
# Run this cell without changes
df["YrSold"].value_counts().sort_index()
# Out:
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: YrSold, dtype: int64

# %% [markdown]
# Maybe we can learn something interesting from the age of the home when it was sold. This uses information from the `YrBuilt` and `YrSold` columns, but represents a truly distinct feature.

# %%
# Run this cell without changes

# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price");

# %% [markdown]
# Interpret this plot below:

# %%
# Replace None with appropriate text
"""
The graph depicts the link between home age at the time of selling and sale price. According to the scatter plot, as a home's age increases, its sale price tends to fall. This implies a negative relationship between home age and sale price. In other words, newer properties typically sell for more than older homes.

"""
# Out:
# "\nThe graph depicts the link between home age at the time of selling and sale price. According to the scatter plot, as a home's age increases, its sale price tends to fall. This implies a negative relationship between home age and sale price. In other words, newer properties typically sell for more than older homes.\n\n"

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed an exploratory data analysis of a popular dataset! You saw how to inspect the distributions of individual columns, subsets of columns, correlations, and new engineered features.
